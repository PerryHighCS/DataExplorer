# %% [markdown]
# # 7.8 - Tell a Data Story
#
# ## Background
# Data tools help us learn from information in the world around us. When we clean, analyze, and visualize data, we can find patterns and tell meaningful stories.
#
# For this project, you will:
# * Choose a dataset
# * Use this notebook and Python to create one or more visualizations
# * Write a short explanation that includes:
#   * what your visualizations show
#   * what new insights or decisions could come from this information
#   * possible issues in your analysis (including data bias or interpretation bias)
#
# You have already practiced coding, cleaning, filtering, and graphing. Now you will combine those skills to tell your own data story.
# You may use a class dataset or find a new one. You may also use Copilot to plan your analysis, debug code, and explain chart results.
#
# Run the next cell to import the libraries you need.

# %%
import pandas # for loading and visualizing data
import numpy # for trendlines if needed

# %% [markdown]
# ## Data Analysis Process
# ### 1. Collect or Choose Data
# * Choose a dataset from the [code.org Data Library](https://learn.mycode.run/link/xzcnh) or [data.gov](https://catalog.data.gov/).
# * Review the dataset metadata so you understand what each column means.
# * Download the dataset as a `.csv` file and place it in the same folder as this notebook.
# * Double click the next cell and fill in the dataset name and provide a short description.

# %% [markdown]
# Dataset name:
#
# Short description of the dataset:

# %% [markdown]
# ### 2. Process Data
# * Open your `.csv` file from the VS Code Explorer.
# * Review the table and decide what needs to be cleaned or filtered.
# * Clean the data as needed, and describe what you changed.
# * Load the data into pandas, then apply your filters.

# %% [markdown]
# ### 3. Visualize and Find Patterns
# * Create at least one visualization that helps explain something interesting in your data.
# * Include clear labels, a title, and anything else needed to read your chart.
# * You may use bar charts, histograms, scatter plots, crosstab charts, or a combination.

# %% [markdown]
# ### 4. Explain New Information
# After your visualization, add a response that explains:
# * what your visualization(s) show
# * what insights or decisions could come from the data
# * possible limits or bias in your data and interpretation
#
# Make sure your response includes all three points.

# %% [markdown]
# ## Tell your story
#
# The rest of this notebook is your workspace.
# Use the process above to explore your dataset and build a clear data story.
#
# As you work, explain your choices:
# * Why did you clean or filter the data this way?
# * Why did you choose these visualization(s)?
# * What should your audience learn from your charts?
#
# Add code and markdown cells as needed to keep your work organized.
# Use `Code` cells for Python and `Markdown` cells for explanation.

# %% [markdown]
# # My Data Story <- Change this title

# %%
# load the data from the csv file

# %%
# automated cleaning of the data

# %%
# filtering the data

# %%
# Create visualizations
